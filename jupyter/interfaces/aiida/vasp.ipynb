# %% [markdown]
# # Guide for twinpy/interfaces/aiida/vasp.py

# %%
# %aiida
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from pprint import pprint
import numpy as np
import twinpy
from twinpy.interfaces.aiida.vasp import _AiidaVaspWorkChain
from twinpy.interfaces.aiida import (AiidaVaspWorkChain,
                                     AiidaRelaxWorkChain,
                                     AiidaRelaxCollection,
                                     )

jupyter_dir = os.path.join(os.path.dirname(twinpy.__file__), '..', 'jupyter')
sys.path.append(os.path.join(jupyter_dir, 'site-packages'))
from jupyter_help import show_info

vasp_pk = 211442  # twinpy
relax_pk = 186753  # twinpy
relax_collection_pks = [186753, 267977, 279276, 282215, 283951]   # twinpy

# %% [markdown]
# # class _AiidaVaspWorkChain

# %%
aiida_vasp_base = _AiidaVaspWorkChain(node=load_node(vasp_pk))
show_info(aiida_vasp_base, is_class=True)
# Out:
# ====== START class information ======
#
# # ---------
# # docstring
# # ---------
#
#     Aiida-Vasp base work chain class.
#
#
# # ----
# # init
# # ----
#
#         Args:
#             node: aiida Node
#
#
# # ---------------
# # attribute names
# # ---------------
# ['_node',
#  '_process_class',
#  '_process_state',
#  '_pk',
#  '_label',
#  '_description',
#  '_exit_status',
#  '_initial_structure_pk',
#  '_initial_cell',
#  '_stress',
#  '_forces',
#  '_energy']
#
# # ------
# # values
# # ------
# {'_description': 'relax_twinboundary',
#  '_energy': -82.10367063,
#  '_exit_status': 0,
#  '_forces': array([[ 0.00000e+00,  0.00000e+00,  2.84390e-04],
#        [ 0.00000e+00, -0.00000e+00, -1.27245e-03],
#        [ 6.35810e-04, -0.00000e+00,  3.27544e-03],
#        [ 1.75690e-04, -0.00000e+00,  2.57515e-03],
#        [-5.83130e-04,  0.00000e+00, -5.81730e-04],
#        [ 1.00200e-05, -0.00000e+00, -4.73300e-05],
#        [-1.75690e-04,  0.00000e+00, -2.57515e-03],
# ...

# %% [markdown]
# ## def get_kpoints_info

# %%
show_info(aiida_vasp_base.get_kpoints_info)
pprint(aiida_vasp_base.get_kpoints_info())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get sampling kpoints information.
#
#         Returns:
#             dict: kpoints information
#
#
# ======= END method information =======
#
#
# {'include_two_pi': True,
#  'intervals': array([0.06941559, 0.14146986, 0.13914262]),
#  'mesh': [2, 14, 6],
#  'offset': [0.5, 0.5, 0.5],
#  'reciprocal_abc': array([0.13883118, 1.98057807, 0.83485575]),
#  'reciprocal_lattice': array([[0.13883118, 0.        , 0.        ],
#        [0.        , 1.98057807, 0.        ],
#        [0.        , 0.        , 0.83485575]]),
#  'reciprocal_volume': 0.2295569439722922,
#  'sampling_kpoints': array([[0.25      , 0.03571429, 0.08333333],
#        [0.25      , 0.10714286, 0.08333333],
#        [0.25      , 0.17857143, 0.08333333],
#        [0.25      , 0.25      , 0.08333333],
#        [0.25      , 0.32142857, 0.08333333],
#        [0.25      , 0.39285714, 0.08333333],
# ...

# %% [markdown]
# ## def get_vasp_settings

# %%
show_info(aiida_vasp_base.get_vasp_settings)
pprint(aiida_vasp_base.get_vasp_settings())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get input parameters.
#
#         Returns:
#             dict: input parameters
#
#
# ======= END method information =======
#
#
# {'incar': {'addgrid': True,
#            'bands': {},
#            'charge': {},
#            'converge': {},
#            'ediff': 1e-06,
#            'electronic': {},
#            'encut': 525,
#            'gga': 'PS',
#            'ialgo': 38,
#            'ismear': 1,
#            'lcharg': False,
#            'lreal': False,
#            'lwave': False,
#            'npar': 4,
#            'prec': 'Accurate',
#            'relax': {'algo': 'cg',
#                      'convergence_absolute': False,
#                      'convergence_max_iterations': 4,
#                      'convergence_on': True,
#                      'convergence_positions': 0.0001,
#                      'convergence_shape_angles': 0.1,
# ...

# %% [markdown]
# ## def get_misc

# %%
show_info(aiida_vasp_base.get_misc)
pprint(aiida_vasp_base.get_misc())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get misc.
#
#
# ======= END method information =======
#
#
# {'magnetization': [],
#  'maximum_force': 0.0033365793186586,
#  'maximum_stress': 2.23937884,
#  'symmetries': {'num_space_group_operations': {'dynamic': [8], 'static': [8]},
#                 'point_group': {'dynamic': ['D_2h.'], 'static': ['D_2h.']},
#                 'primitive_translations': [1]},
#  'total_energies': {'energy_no_entropy': -82.10404964}}

# %% [markdown]
# # class AiidaVaspWorkChain

# %%
aiida_vasp = AiidaVaspWorkChain(node=load_node(vasp_pk),
                                ignore_warning=False)
show_info(aiida_vasp, is_class=True)
# Out:
# ====== START class information ======
#
# # ---------
# # docstring
# # ---------
#
#     Vasp work chain class.
#
#
# # ----
# # init
# # ----
#
#         Args:
#             node: aiida Node
#
#
# # ---------------
# # attribute names
# # ---------------
# ['_node',
#  '_process_class',
#  '_process_state',
#  '_pk',
#  '_label',
#  '_description',
#  '_exit_status',
#  '_initial_structure_pk',
#  '_initial_cell',
#  '_stress',
#  '_forces',
#  '_energy',
#  '_final_structure_pk',
#  '_final_cell']
#
# # ------
# # values
# # ------
# {'_description': 'relax_twinboundary',
#  '_energy': -82.10367063,
#  '_exit_status': 0,
#  '_final_cell': (array([[45.25773786,  0.        ,  0.        ],
#        [ 0.        ,  3.17239971,  0.        ],
#        [ 0.        ,  0.        ,  7.526073  ]]),
#                  array([[0.75      , 0.5       , 0.79326943],
#        [0.75      , 0.5       , 0.37913021],
#        [0.2150023 , 0.        , 0.9005362 ],
# ...

# %% [markdown]
# ## def get_pks

# %%
show_info(aiida_vasp.get_pks)
pprint(aiida_vasp.get_pks())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get pks.
#
#         Returns:
#             dict: containing vasp pk and structure pk
#
#
# ======= END method information =======
#
#
# {'final_structure_pk': 218859,
#  'initial_structure_pk': 211438,
#  'vasp_pk': 211442}

# %% [markdown]
# ## def get_relax_analyzer

# %%
show_info(aiida_vasp.get_relax_analyzer)
print(aiida_vasp.get_relax_analyzer())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get RelaxAnalyzer class object.
#
#         Args:
#             original_cell (tuple): Original cell whose standardized cell
#                                    is initail_cell.
#
#         Returns:
#             RelaxAnalyzer: RelaxAnalyzer class object.
#
#
# ======= END method information =======
#
#
# ...

# %% [markdown]
# ## def get_description

# %%
show_info(aiida_vasp.get_description)
aiida_vasp.get_description()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get description.
#
#
# ======= END method information =======
#
#
# # ---------------
# # About This Node
# # ---------------
# process class:VaspWorkChain
# process state:finished
# pk:211442
# label:relax_twinboundary
# description:relax_twinboundary
# exit status:0
#
#
#
# # ---
# # PKs
# # ---
# {'final_structure_pk': 218859,
#  'initial_structure_pk': 211438,
#  'vasp_pk': 211442}
#
#
#
# # -------------
# # VASP settings
# # -------------
# {'incar': {'addgrid': True,
#            'bands': {},
#            'charge': {},
#            'converge': {},
#            'ediff': 1e-06,
#            'electronic': {},
#            'encut': 525,
#            'gga': 'PS',
#            'ialgo': 38,
#            'ismear': 1,
#            'lcharg': False,
#            'lreal': False,
#            'lwave': False,
#            'npar': 4,
#            'prec': 'Accurate',
# ...

# %% [markdown]
# # class AiidaRelaxWorkChain

# %%
aiida_relax = AiidaRelaxWorkChain(node=load_node(relax_pk))
show_info(aiida_relax, is_class=True)
# Out:
# ====== START class information ======
#
# # ---------
# # docstring
# # ---------
#
#     Relax work chain class.
#
#
# # ----
# # init
# # ----
#
#         Args:
#             node: aiida Node
#
#         Todo:
#             Fix names. Name 'final_cell' 'final_structure_pk' 'cuurent-'
#             are strange because final_cell and final_structure_pk
#             the result from first relax pk. Therefore, 'current-'
#             is truely final structure pk and final cell.
#
#
# # ---------------
# # attribute names
# # ---------------
# ['_node',
#  '_process_class',
#  '_process_state',
#  '_pk',
#  '_label',
#  '_description',
#  '_exit_status',
#  '_initial_structure_pk',
#  '_initial_cell',
#  '_stress',
#  '_forces',
#  '_energy',
#  '_final_structure_pk',
#  '_final_cell',
#  '_current_final_structure_pk',
#  '_current_final_cell']
#
# # ------
# # values
# # ------
# {'_current_final_cell': (array([[ 3.17239971,  0.        ,  0.        ],
# ...

# %% [markdown]
# ## def get_relax_settings

# %%
show_info(aiida_relax.get_relax_settings)
pprint(aiida_relax.get_relax_settings())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get relax settings.
#
#         Returns:
#             dict: relax settings
#
#
# ======= END method information =======
#
#
# {'algo': 'cg',
#  'convergence_absolute': False,
#  'convergence_max_iterations': 4,
#  'convergence_on': True,
#  'convergence_positions': 0.0001,
#  'convergence_shape_angles': 0.1,
#  'convergence_shape_lengths': 0.1,
#  'convergence_volume': 0.01,
#  'force_cutoff': 0.0001,
#  'perform': True,
#  'positions': True,
#  'shape': False,
#  'steps': 60,
#  'volume': False}

# %% [markdown]
# ## def get_vasp_calculation_pks

# %%
show_info(aiida_relax.get_vasp_calculation_pks)
pprint(aiida_relax.get_vasp_calculation_pks())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get VaspWorkChain pks.
#
#         Returns:
#             tuple: (relax_calcs, static_calc)
#
#
# ======= END method information =======
#
#
# ([187216, 189210, 189512], 200149)

# %% [markdown]
# ## def get_vasp_calculations

# %%
show_info(aiida_relax.get_vasp_calculations)
pprint(aiida_relax.get_vasp_calculations())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get AiidaVaspWorkChain class objects.
#
#         Returns:
#             tuple: (relax_calcs, static_calc)
#
#
# ======= END method information =======
#
#
# ([<twinpy.interfaces.aiida.vasp.AiidaVaspWorkChain object at 0x7fd456dd2990>,
# ...
#  <twinpy.interfaces.aiida.vasp.AiidaVaspWorkChain object at 0x7fd478bdd310>)

# %% [markdown]
# ## def get_pks

# %%
show_info(aiida_relax.get_pks)
pprint(aiida_relax.get_pks())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get pks.
#
#         Returns:
#             dict: containing relax pk and structure pk
#
#
# ======= END method information =======
#
#
# {'current_final_structure_pk': 200018,
#  'final_structure_pk': 200018,
#  'initial_structure_pk': 186697,
#  'relax_pk': 186753,
#  'static_pk': 200149,
#  'vasp_relax_pks': [187216, 189210, 189512]}

# %% [markdown]
# ## def get_relax_analyzer

# %%
show_info(aiida_relax.get_relax_analyzer)
print(aiida_relax.get_relax_analyzer())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get RelaxAnalyzer class object.
#
#         Args:
#             original_cell (tuple): Original cell whose standardized cell
#                                    is initail_cell.
#
#         Returns:
#             RelaxAnalyzer: RelaxAnalyzer class object.
#
#
# ======= END method information =======
#
#
# ...

# %% [markdown]
# ## def get_relaxplot

# %%
show_info(aiida_relax.get_relaxplot)
relaxplot = aiida_relax.get_relaxplot()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get RelaxPlot class object.
#
#
# ======= END method information =======

# %% [markdown]
# ## def plot_convergence

# %%
show_info(aiida_relax.plot_convergence)
fig = aiida_relax.plot_convergence()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Plot convergence.
#
#         Todo:
#             This function must be moved in plot directory.
#
#
# ======= END method information =======

# %% [markdown]
# ## def get_description

# %%
show_info(aiida_relax.get_description)
aiida_relax.get_description()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get description.
#
#
# ======= END method information =======
#
#
# # ---------------
# # About This Node
# # ---------------
# process class:RelaxWorkChain
# process state:finished
# pk:186753
# label:relax_twinboundary
# description:relax_twinboundary
# exit status:0
#
#
#
# # ---
# # PKs
# # ---
# {'current_final_structure_pk': 200018,
#  'final_structure_pk': 200018,
#  'initial_structure_pk': 186697,
#  'relax_pk': 186753,
#  'static_pk': 200149,
#  'vasp_relax_pks': [187216, 189210, 189512]}
#
#
#
# # --------------
# # relax settings
# # --------------
# {'algo': 'cg',
#  'convergence_absolute': False,
#  'convergence_max_iterations': 4,
#  'convergence_on': True,
#  'convergence_positions': 0.0001,
#  'convergence_shape_angles': 0.1,
#  'convergence_shape_lengths': 0.1,
#  'convergence_volume': 0.01,
#  'force_cutoff': 0.0001,
#  'perform': True,
#  'positions': True,
# ...

# %% [markdown]
# # Class AiidaRelaxCollection class

# %%
aiida_relaxes = [ AiidaRelaxWorkChain(load_node(pk)) for pk in relax_collection_pks ]
relax_collection = AiidaRelaxCollection(aiida_relaxes=aiida_relaxes)
show_info(relax_collection, is_class=True)
# Out:
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/base.py:105: UserWarning: process state: excepted
#   warnings.warn("process state: %s" % self._process_state)
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:309: UserWarning: Final structure could not find.
# process state:excepted (pk=279276)
#   self.process_state, self._node.pk))
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:371: UserWarning: Could not find final static_pk calculation.
#   warnings.warn("Could not find final static_pk calculation.")
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:212: UserWarning: Final structure could not find.
# process state:excepted (pk=281156)
#   self.process_state, self._node.pk))
# ====== START class information ======
#
# # ---------
# # docstring
# # ---------
#
#     Collection of AiidaRelaxWorkChain.
#
#
# # ----
# # init
# # ----
#
#         Args:
# ...

# %% [markdown]
# ## def get_pks

# %%
show_info(relax_collection.get_pks)
pprint(relax_collection.get_pks())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get pks.
#
#
# ======= END method information =======
#
#
# {'aiida_relax_pks': [186753, 267977, 279276, 282215, 283951],
#  'current_final_structure_pk': 285033,
#  'final_structure_pk': 285033,
#  'initial_structure_pk': 186697}

# %% [markdown]
# ## def get_relax_analyzer

# %%
show_info(relax_collection.get_relax_analyzer)
relax_analyzer = relax_collection.get_relax_analyzer()
print(relax_analyzer)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get RelaxAnalyzer class object.
#
#         Args:
#             original_cell (tuple): Original cell whose standardized cell
#                                    is initail_cell.
#
#
# ======= END method information =======
#
#
# ...

# %% [markdown]
# ## def get_relaxplots

# %%
show_info(relax_collection.get_relaxplots)
relax_plots = relax_collection.get_relaxplots()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get RelaxPlot class objects.
#
#
# ======= END method information =======
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:371: UserWarning: Could not find final static_pk calculation.
#   warnings.warn("Could not find final static_pk calculation.")

# %% [markdown]
# ## def plot_convergence

# %%
show_info(relax_collection.plot_convergence)
fig = relax_collection.plot_convergence()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get RelaxPlot class objects.
#
#
# ======= END method information =======
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:371: UserWarning: Could not find final static_pk calculation.
#   warnings.warn("Could not find final static_pk calculation.")
