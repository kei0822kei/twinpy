# %% [markdown]
# # Guide for twinpy/interfaces/aiida/phonopy.py

# %%
# %aiida
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pprint import pprint
import numpy as np
import twinpy
from twinpy.interfaces.aiida import (AiidaRelaxWorkChain,
                                     AiidaPhonopyWorkChain,
                                     get_cell_from_aiida
                                     )
from twinpy.analysis import RelaxAnalyzer

jupyter_dir = os.path.join(os.path.dirname(twinpy.__file__), '..', 'jupyter')
sys.path.append(os.path.join(jupyter_dir, 'site-packages'))
from jupyter_help import show_info

shear_orig_structure_pk = 315869  # twinpy Ti_pv shear_orig_003
relax_pk = 316006  # twinpy Ti_pv shear_003 relax
phonopy_pk = 318866  # twinpy Ti_pv shear_003 phonon

# %% [markdown]
# # class AiidaPhonopyWorkChain

# %%
aiida_phonopy = AiidaPhonopyWorkChain(load_node(phonopy_pk))
show_info(aiida_phonopy, is_class=True)
# Out:
# ====== START class information ======
#
# # ---------
# # docstring
# # ---------
#
#     Phononpy work chain class.
#
#
# # ----
# # init
# # ----
#
#         Args:
#             node: aiida Node
#
#
# # ---------------
# # attribute names
# # ---------------
# ['_node',
#  '_process_class',
#  '_process_state',
#  '_pk',
#  '_label',
#  '_description',
#  '_exit_status',
#  '_unitcell',
#  '_phonon_settings',
#  '_phonon_setting_info',
#  '_primitive',
#  '_supercell',
#  '_structure_pks',
#  '_force_sets']
#
# # ------
# # values
# # ------
# {'_description': 'ph_shear_003, ratio: 0.333333',
#  '_exit_status': 0,
#  '_force_sets': array([[[-1.8666325e-01,  9.3331740e-02, -1.5408600e-03],
#         [ 4.7931000e-02, -8.4172500e-03,  1.3913000e-04],
#         [ 9.5561100e-03, -6.1889100e-03, -4.5280000e-05],
#         ...,
#         [-3.8147300e-03,  2.5663500e-03,  5.1001400e-03],
#         [-2.4607900e-03,  1.4896100e-03,  2.5684000e-04],
#         [-4.5888600e-03,  1.8108400e-03, -5.4461100e-03]],
#
#        [[ 1.8539088e-01, -9.0524210e-02,  1.4666400e-03],
#         [-4.3820940e-02,  6.2043000e-03, -1.8230000e-04],
#         [-9.8029000e-03,  5.9114900e-03,  1.7600000e-06],
#         ...,
#         [ 3.6324800e-03, -2.5586700e-03, -5.1136500e-03],
#         [ 2.5110200e-03, -1.6263100e-03, -2.4990000e-04],
#         [ 4.5653900e-03, -1.8726800e-03,  5.3743500e-03]],
#
#        [[-1.3273800e-03, -0.0000000e+00, -1.5799308e-01],
#         [-3.6239000e-04,  2.9194000e-04,  7.9347000e-03],
#         [-1.0752000e-04, -6.9350000e-05, -1.4518100e-03],
#         ...,
#         [ 3.0721300e-03, -5.0459100e-03, -6.3055600e-03],
#         [ 4.1203000e-04,  1.5518000e-04,  1.3550600e-03],
#         [-6.2364700e-03, -0.0000000e+00, -6.8754900e-03]],
#
#        [[ 6.1103000e-04,  0.0000000e+00,  1.5799324e-01],
#         [-5.0251000e-04,  2.8465000e-04, -8.0028900e-03],
#         [-1.8400000e-06, -1.1730000e-04,  1.4099800e-03],
#         ...,
#         [-2.9164300e-03,  4.9318900e-03,  6.3322700e-03],
#         [-3.6690000e-04, -1.2781000e-04, -1.3780600e-03],
#         [ 6.3182000e-03,  0.0000000e+00,  7.0413900e-03]]]),
#  '_label': 'ph_shear_003',
#  '_node': <WorkChainNode: uuid: 98128b15-8da0-410a-adba-d30065d64200 (pk: 318866) (aiida.workflows:phonopy.phonopy)>,
#  '_phonon_setting_info': {'displacement_dataset': {'first_atoms': [{'displacement': [0.025781912732559,
#                                                                                      -0.015339262558895,
#                                                                                      0.0],
#                                                                     'number': 0},
#                                                                    {'displacement': [-0.025781912732559,
#                                                                                      0.015339262558895,
#                                                                                      0.0],
#                                                                     'number': 0},
#                                                                    {'displacement': [-0.00010835704215136,
#                                                                                      0.0,
#                                                                                      0.029999804311885],
#                                                                     'number': 0},
#                                                                    {'displacement': [0.00010835704215136,
#                                                                                      0.0,
#                                                                                      -0.029999804311885],
#                                                                     'number': 0}],
#                                                    'natom': 96},
#                           'distance': 0.03,
#                           'is_nac': False,
#                           'mesh': [18, 18, 10],
#                           'primitive_matrix': [[1.0,
#                                                 1.1102230246252e-16,
#                                                 -4.7704895589362e-18],
#                                                [1.1102230246252e-16,
#                                                 1.0,
#                                                 -4.7704895589362e-18],
#                                                [0.0, 0.0, 1.0]],
#                           'supercell_matrix': [[4, 0, 0], [0, 4, 0], [0, 0, 3]],
#                           'symmetry': {'international': 'C2/m', 'number': 12},
#                           'symmetry_tolerance': 1e-05},
#  '_phonon_settings': {'distance': 0.03,
#                       'is_nac': False,
#                       'mesh': [18, 18, 10],
#                       'supercell_matrix': [4, 4, 3],
#                       'symmetry_tolerance': 1e-05},
#  '_pk': 318866,
#  '_primitive': (array([[ 2.43641971, -1.44957754,  0.        ],
#        [ 2.43641971,  1.44957754,  0.        ],
#        [-0.01707824,  0.        ,  4.72829313]]),
#                 array([[0.32759891, 0.32759891, 0.24996677],
#        [0.67240109, 0.67240109, 0.75003323]]),
#                 ['Ti', 'Ti']),
#  '_process_class': 'PhonopyWorkChain',
#  '_process_state': 'finished',
#  '_structure_pks': {'primitive_pk': 318899,
#                     'supercell_pk': 318895,
#                     'unitcell_pk': 318048},
#  '_supercell': (array([[ 9.74567884, -5.79831016,  0.        ],
#        [ 9.74567884,  5.79831016,  0.        ],
#        [-0.05123472,  0.        , 14.18487939]]),
#                 array([[0.08189973, 0.08189973, 0.08332226],
#        [0.33189973, 0.08189973, 0.08332226],
#        [0.58189973, 0.08189973, 0.08332226],
#        [0.83189973, 0.08189973, 0.08332226],
#        [0.08189973, 0.33189973, 0.08332226],
#        [0.33189973, 0.33189973, 0.08332226],
#        [0.58189973, 0.33189973, 0.08332226],
#        [0.83189973, 0.33189973, 0.08332226],
#        [0.08189973, 0.58189973, 0.08332226],
#        [0.33189973, 0.58189973, 0.08332226],
#        [0.58189973, 0.58189973, 0.08332226],
#        [0.83189973, 0.58189973, 0.08332226],
#        [0.08189973, 0.83189973, 0.08332226],
#        [0.33189973, 0.83189973, 0.08332226],
#        [0.58189973, 0.83189973, 0.08332226],
#        [0.83189973, 0.83189973, 0.08332226],
#        [0.08189973, 0.08189973, 0.41665559],
#        [0.33189973, 0.08189973, 0.41665559],
#        [0.58189973, 0.08189973, 0.41665559],
#        [0.83189973, 0.08189973, 0.41665559],
#        [0.66810027, 0.41810027, 0.91667774],
#        [0.91810027, 0.41810027, 0.91667774],
#        [0.16810027, 0.66810027, 0.91667774],
#        [0.41810027, 0.66810027, 0.91667774],
#        [0.66810027, 0.66810027, 0.91667774],
#        [0.91810027, 0.66810027, 0.91667774],
#        [0.16810027, 0.91810027, 0.91667774],
#        [0.41810027, 0.91810027, 0.91667774],
#        [0.66810027, 0.91810027, 0.91667774],
#        [0.91810027, 0.91810027, 0.91667774]]),
#                 ['Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti',
#                  'Ti']),
#  '_unitcell': (array([[ 2.43641971, -1.44957754,  0.        ],
#        [ 2.43641971,  1.44957754,  0.        ],
#        [-0.01707824,  0.        ,  4.72829313]]),
#                array([[0.32759891, 0.32759891, 0.24996677],
#        [0.67240109, 0.67240109, 0.75003323]]),
#                ['Ti', 'Ti'])}
#
# ======= END class information =======

# %% [markdown]
# ## def get_pks

# %%
show_info(aiida_phonopy.get_pks)
pprint(aiida_phonopy.get_pks())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get pks.
#
#         Returns:
#             dict: Containing phonopy pk and structure pk.
#
#
# ======= END method information =======
#
#
# {'phonopy_pk': 318866,
#  'primitive_pk': 318899,
#  'supercell_pk': 318895,
#  'unitcell_pk': 318048}

# %% [markdown]
# ## def get_phonon

# %%
show_info(aiida_phonopy.get_phonon)
print(aiida_phonopy.get_phonon())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get phonopy object.
#
#         Returns:
#             phonon: Phonopy class object.
#
#
# ======= END method information =======
#
#
# <phonopy.api_phonopy.Phonopy object at 0x7fd3c21b4410>

# %% [markdown]
# ## def get_description

# %%
show_info(aiida_phonopy.get_description)
aiida_phonopy.get_description()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get description.
#
#
# ======= END method information =======
#
#
# # ---------------
# # About This Node
# # ---------------
# process class:PhonopyWorkChain
# process state:finished
# pk:318866
# label:ph_shear_003
# description:ph_shear_003, ratio: 0.333333
# exit status:0
#
#
#
# # ---
# # PKs
# # ---
# {'phonopy_pk': 318866,
#  'primitive_pk': 318899,
#  'supercell_pk': 318895,
#  'unitcell_pk': 318048}
#
#
#
# # ----------------
# # phonopy settings
# # ----------------
# {'distance': 0.03,
#  'is_nac': False,
#  'mesh': [18, 18, 10],
#  'supercell_matrix': [4, 4, 3],
#  'symmetry_tolerance': 1e-05}

# %% [markdown]
# ## def get_phonon_analyzer

# %%
show_info(aiida_phonopy.get_phonon_analyzer)
aiida_relax = AiidaRelaxWorkChain(load_node(relax_pk))
original_cell = get_cell_from_aiida(load_node(shear_orig_structure_pk))
relax_analyzer = aiida_relax.get_relax_analyzer(original_cell=original_cell)
phonon_analyzer = aiida_phonopy.get_phonon_analyzer(relax_analyzer=relax_analyzer)
print(phonon_analyzer)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get PhononAnalyzer class object.
#
#         Args:
#             relax_analyzer: RelaxAnalyzer class object.
#
#
# ======= END method information =======
#
#
# <twinpy.analysis.phonon_analyzer.PhononAnalyzer object at 0x7fd3bfff1610>
