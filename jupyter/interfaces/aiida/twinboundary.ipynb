# %% [markdown]
# # Guide for twinpy/interfaces/aiida/twinboundary.py

# %%
# %aiida
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pprint import pprint
import numpy as np
import twinpy

from twinpy.interfaces.aiida import AiidaTwinBoudnaryRelaxWorkChain

jupyter_dir = os.path.join(os.path.dirname(twinpy.__file__), '..', 'jupyter')
sys.path.append(os.path.join(jupyter_dir, 'site-packages'))
from jupyter_help import show_info

bulk_relax_pk = 7887  # twinpy
twinboundary_relax_pk = 186343  # twinpy
additional_relax_pks = [267977, 279276, 282215, 283951]   # twinpy

# %% [markdown]
# # class TwinBoudnaryRelax

# %%
aiida_twinboundary_relax = AiidaTwinBoudnaryRelaxWorkChain(node=load_node(twinboundary_relax_pk))
show_info(aiida_twinboundary_relax, is_class=True)
# Out:
# ====== START class information ======
#
# # ---------
# # docstring
# # ---------
#
#     TwinBoundaryRelax work chain class.
#
#
# # ---------------
# # attribute names
# # ---------------
# ['_node',
#  '_process_class',
#  '_process_state',
#  '_pk',
#  '_label',
#  '_description',
#  '_exit_status',
#  '_twinboundary_settings',
#  '_cells',
#  '_structure_pks',
#  '_twinpy',
#  '_standardize',
#  '_additional_relax_pks']
#
# # ------
# # values
# # ------
# {'_additional_relax_pks': [],
#  '_cells': {'hexagonal': (array([[ 3.17239971,  0.        ,  0.        ],
#        [-1.58619985,  2.74737874,  0.        ],
#        [ 0.        ,  0.        ,  5.14289947]]),
#                           array([[0.33333333, 0.66666667, 0.25      ],
#        [0.66666667, 0.33333333, 0.75      ]]),
#                           ['Mg', 'Mg']),
#             'twinboundary': (array([[ 3.17239971,  0.        ,  0.        ],
#        [ 0.        , 41.30292637,  0.        ],
# ...

# %% [markdown]
# ## set additional relax

# %%
show_info(aiida_twinboundary_relax.set_additional_relax)
aiida_twinboundary_relax.set_additional_relax(additional_relax_pks)
print("")
print("# -------------------------------------")
print("# class object after settings relax pks")
print("# -------------------------------------")
print("")
show_info(aiida_twinboundary_relax, is_class=True)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Set additional_relax_pks in the case final structure of
#         TwinBoundaryRelax WorkChain is further relaxed.
#
#         Args:
#             aiida_relaxes (list): list of relax pks
#
#         Raises:
#             RuntimeError: Input node is not RelaxWorkChain
#             RuntimeError: Output structure and next input structure
#                           does not match.
#
#
# ======= END method information =======
#
#
#
# # -------------------------------------
# # class object after settings relax pks
# # -------------------------------------
#
# ====== START class information ======
#
# # ---------
# # docstring
# # ---------
#
#     TwinBoundaryRelax work chain class.
#
#
# # ---------------
# # attribute names
# # ---------------
# ['_node',
#  '_process_class',
#  '_process_state',
#  '_pk',
#  '_label',
#  '_description',
#  '_exit_status',
#  '_twinboundary_settings',
# ...

# %% [markdown]
# ## def get_pks

# %%
show_info(aiida_twinboundary_relax.get_pks)
pprint(aiida_twinboundary_relax.get_pks())
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get pks.
#
#
# ======= END method information =======
#
#
# {'additional_relax_pks': [267977, 279276, 282215, 283951],
#  'relax_pk': 186753,
#  'twinboundary_pk': 186343}

# %% [markdown]
# ## def get_diff

# %%
show_info(aiida_twinboundary_relax.get_diff)
pprint(aiida_twinboundary_relax.get_diff(use_additional_relax=False))
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get diff between vasp input and output twinboundary structure.
#
#         Args:
#             use_additional_relax (bool): if True, output twinboundary structure
#                                          becomes the final structure of
#                                          additional_relax
#
#         Returns:
#             dict: diff between vasp input and output twinboundary structure
#
#         Raises:
#             AssertionError: lattice matrix is not identical
#
#
# ======= END method information =======
#
#
# {'cart_norm_diffs': array([[0.09413891, 0.11981245, 0.06022271, 0.06182965, 0.1085495 ,
#         0.21778064, 0.00389278, 0.00176855, 0.02223026, 0.02761896,
#         0.00341796, 0.00281346, 0.00281346, 0.00341796, 0.02761896,
#         0.02223026, 0.00176855, 0.00389278, 0.21778064, 0.1085495 ,
#         0.06182965, 0.06022271, 0.11981245, 0.0941389 , 0.06022271,
# ...

# %% [markdown]
# ## def get_planes_angles

# %%
show_info(aiida_twinboundary_relax.get_planes_angles)
pprint(aiida_twinboundary_relax.get_planes_angles(
           is_fractional=False,
           use_additional_relax=False))
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get plane coords from lower plane to upper plane.
#         Return list of z coordinates of original cell frame.
#
#         Args:
#             is_fractional (bool): if True, return with fractional coordinate
#             use_additional_relax (bool): if True, output twinboundary structure
#                                          becomes the final structure of
#                                          additional_relax
#
#         Returns:
#             dict: plane coords of input and output twinboundary structures.
#
#
# ======= END method information =======
#
#
# {'angles': {'before': array([ 0.        , 11.43304902, 11.43304902, 11.43304902, 11.43304902,
#        11.43304902, 11.43304902, 11.43304902, 11.43304902, 11.43304902,
#        11.43304902,  0.        , 11.43304902, 11.43304902, 11.43304902,
#        11.43304902, 11.43304902, 11.43304902, 11.43304902, 11.43304902,
# ...

# %% [markdown]
# ## def get_distances

# %%
show_info(aiida_twinboundary_relax.get_distances)
aiida_twinboundary_relax.get_distances(
    is_fractional=False,
    use_additional_relax=False)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get distances from the result of 'get_planes'.
#
#         Args:
#             is_fractional (bool): if True, return with fractional coordinate
#             use_additional_relax (bool): if True, output twinboundary structure
#                                          becomes the final structure of
#                                          additional_relax
#
#         Returns:
#             dict: distances between planes of input and output
#                   twinboundary structures.
#
#
# ======= END method information =======
# {'before': [1.87740593,
#   1.8774055200000002,
#   1.8774059300000001,
#   1.87740594,
#   1.8774050999999998,
#   1.8774059300000001,
#   1.8774059300000001,
#   1.87740552,
#   1.8774059399999992,
#   1.8774059300000019,
#   1.87740552,
#   1.8774055099999991,
#   1.8774059399999992,
#   1.8774059300000019,
#   1.87740552,
#   1.8774059299999983,
# ...

# %% [markdown]
# ## def get_formation_energy

# %%
show_info(aiida_twinboundary_relax.get_formation_energy)
aiida_twinboundary_relax.get_formation_energy(
    bulk_relax_pk=bulk_relax_pk)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get formation energy. Unit [mJ/m^(-2)]
#
#         Args:
#             bulk_relax_pk: relax pk of bulk relax calculation
#
#
# ======= END method information =======
# 139.1241761281626

# %% [markdown]
# ## def plot_convergence

# %%
show_info(aiida_twinboundary_relax.plot_convergence)
aiida_twinboundary_relax.plot_convergence()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Plot convergence.
#
#
# ======= END method information =======
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:337: UserWarning: RelaxWorkChain (pk=279276) state is excepted
#   aiida_relax.pk, aiida_relax.process_state.value))
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/base.py:89: UserWarning: process state: excepted
#   warnings.warn("process state: %s" % self._process_state)
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:286: UserWarning: Final structure could not find.
# process state:excepted (pk=279276)
#   self.process_state, self._node.pk))
# /home/mizo/src/github.com/kei0822kei/twinpy/twinpy/interfaces/aiida/vasp.py:393: UserWarning: Could not find final static_pk calculation.
#   warnings.warn("Could not find final static_pk calculation.")
# ...

# %% [markdown]
# ## def plot_plane_diff

# %%
show_info(aiida_twinboundary_relax.plot_plane_diff)
aiida_twinboundary_relax.plot_plane_diff(
    is_fractional=True,
    is_decorate=True,
    use_additional_relax=True)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Plot plane diff.
#
#         Args:
#             is_fractional (bool): if True, z coords with fractional coordinate
#             is_decorate (bool): if True, decorate figure
#             use_additional_relax (bool): if True, output twinboundary structure
#                                          becomes the final structure of
#                                          additional_relax
#
#
# ======= END method information =======

# %% [markdown]
# ## def plot_angle_diff

# %%
show_info(aiida_twinboundary_relax.plot_angle_diff)
aiida_twinboundary_relax.plot_angle_diff(
    is_fractional=True,
    is_decorate=True,
    use_additional_relax=True)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Plot angle diff.
#
#         Args:
#             is_fractional (bool): if True, z coords with fractional coordinate
#             is_decorate (bool): if True, decorate figure
#             use_additional_relax (bool): if True, output twinboundary structure
#                                          becomes the final structure of
#                                          additional_relax
#
#
# ======= END method information =======

# %% [markdown]
# ## def get_description

# %%
show_info(aiida_twinboundary_relax.get_description)
aiida_twinboundary_relax.get_description()
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get description.
#
#
# ======= END method information =======
#
#
# # ---------------
# # About This Node
# # ---------------
# process class:TwinBoundaryRelaxWorkChain
# process state:finished
# pk:186343
# label:Mg_pv 10-12 ly:10 dl:0.0
# description:Mg_pv 10-12 layers:10 delta:0.0
# exit status:0
#
#
#
# # ---
# # PKs
# # ---
# {'additional_relax_pks': [267977, 279276, 282215, 283951],
#  'relax_pk': 186753,
#  'twinboundary_pk': 186343}
#
#
#
# # ---------------------
# # twinboudnary settings
# # ---------------------
# {'delta': 0.0,
#  'get_lattice': False,
#  'get_sort_list': False,
#  'layers': 10,
#  'move_atoms_into_unitcell': True,
#  'no_idealize': False,
#  'no_sort': True,
#  'shear_strain_ratio': 0.0,
#  'symprec': 1e-05,
#  'to_primitive': True,
#  'twinmode': '10-12',
#  'twintype': 1,
#  'xshift': 0.0,
#  'yshift': 0.0}

# %% [markdown]
# ## def get_shear_cell

# %%
show_info(aiida_twinboundary_relax.get_shear_cell)
aiida_twinboundary_relax.get_shear_cell(
    shear_strain_ratio=0.1,
    is_standardize=False)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get shear introduced twinboundary cell.
#
#         Args:
#             shear_strain_ratio (float): shear strain ratio
#             is_standardize (bool): if True, get standardized cell
#
#         Returns:
#             tuple: shear introduced cell
#
#
# ======= END method information =======
#
#
# get cell (twinboundary_additional_relax_original cell)
# (array([[ 3.19290368e+00, -2.25468063e-09, -2.82290305e-16],
#         [ 5.30689606e-09,  7.51521423e+00,  6.95899329e-48],
#         [ 3.85668659e-10,  5.46148854e-01,  4.12338767e+01]]),
#  array([[0.5       , 0.18987817, 0.        ],
#         [0.5       , 0.77415617, 0.        ],
#         [0.5       , 0.67037014, 0.09686977],
#         [0.5       , 0.2565298 , 0.08491331],
#         [0.        , 0.95006954, 0.05376716],
#         [0.        , 0.49517744, 0.03823999],
#         [0.5       , 0.13946881, 0.18920264],
# ...

# %% [markdown]
# ## def get_shear_relax_builder

# %%
show_info(aiida_twinboundary_relax.get_shear_relax_builder)
aiida_twinboundary_relax.get_shear_relax_builder(
    shear_strain_ratio=0.1)
# Out:
# ====== START method information ======
#
# # ---------
# # docstring
# # ---------
#
#         Get relax builder for shear introduced relax twinboundary structure.
#
#         Args:
#             shear_strain_ratio (float): shear strain ratio
#
#
# ======= END method information =======
#
#
# get cell (twinboundary_additional_relax_original cell)
# /home/mizo/project/twin/site-packages/aiida-core/aiida/orm/computers.py:741: AiidaDeprecationWarning: this property is deprecated, use the `label` property instead
#   warnings.warn('this property is deprecated, use the `label` property instead', AiidaDeprecationWarning)  # pylint: disable=no-member
# ...
